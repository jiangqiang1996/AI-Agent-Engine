# %% [markdown]
# # Jupyter Notebook Sample
#
# This is a test notebook.

# %%
print('hello world')
# Out:
# hello world

# %%
import numpy as np
x = np.array([1, 2, 3])

# %% [raw]
# This is raw content

# %% [markdown]
# ## Conclusion
#
# The result is **bold**.
